# %% [markdown]
# # The Cumulative Distribution Function - Lab
#
# ## Introduction
#
# In the previous lesson, you learned how you can create a cumulative distribution function for discrete and continuous random variables. In this lab, you'll try to calculate a CDF for a dice roll yourself, and visualize it.
#
# ## Objectives
# You will be able to:
#
# * Calculate CDF in Python for a given discrete variable with a limited set of possible values
# * Visualize and inspect a CDF in order to make assumptions about the underlying data

# %% [markdown]
# ## Calculating CDF in Python
#
# Recall the formula to calculate the cumulative probability from the previous lesson:
#
# $$\Large F(x)= P(X \leq x)$$
#
# So given a list of all possible values of x, We can easily calculate the CDF for a given possible value $X$ by performing the following steps:
#
# * Build a function `calculate_cdf(lst,X)`, where `lst` is a list of all possible values in a discrete variable $x$ (6 values for a dice roll), and $X$ is the value for which we want to calculate the cumulative distribution function
# * Initialize a variable called `count`
# * For all values in `lst`, if a value is less than or equal to $X$, add one to `count` - do nothing otherwise. (this will tell us the total number of values less than $X$)
# * Calculate the cumulative probability of $X$ dividing `count` by the total number of possible values
# * Round by 3 decimals and return the cumulative probability of $X$

# %%
def calculate_cdf(lst, X):
    # Sort the list
    sorted_lst = sorted(lst)
    
    # Count the number of elements less than or equal to X
    count = sum(1 for i in sorted_lst if i <= X)
    
    # Calculate the CDF
    cdf = count / len(sorted_lst)
    
    return cdf

# Test data
test_lst = [1, 2, 3]
test_X = 2

# Calculate CDF
result = calculate_cdf(test_lst, test_X)
print(result)  
# Output: 0.667
# Out:
# 0.6666666666666666

# %% [markdown]
# Now, use this function to calculate a CDF for each value in a dice roll so you can plot it later on.

# %% [markdown]
# Perform the following steps in the cell below:
# * Create a list `dice_lst` with all possible values of a fair dice
# * Initialize an empty list `dice_cum` for storing cumulative probabilities for these values.
# * For each value in the `dice_lst` calculate its cumulative probability using the function above and store in `dice_cum` list.

# %%
def calculate_cdf(lst, X):
    # Sort the list
    sorted_lst = sorted(lst)
    
    # Count the number of elements less than or equal to X
    count = sum(1 for i in sorted_lst if i <= X)
    
    # Calculate the CDF
    cdf = count / len(sorted_lst)
    
    return cdf

# Step 1: Create a list with all possible values of a fair dice
dice_lst = [1, 2, 3, 4, 5, 6]

# Step 2: Initialize an empty list for storing cumulative probabilities
dice_cum = []

# Step 3: Calculate the cumulative probability for each value in dice_lst
for value in dice_lst:
    cdf_value = calculate_cdf(dice_lst, value)
    dice_cum.append(cdf_value)

# Print the cumulative probabilities
dice_cum

# [0.167, 0.333, 0.5, 0.667, 0.833, 1.0]
# Out:
# [0.16666666666666666,
#  0.3333333333333333,
#  0.5,
#  0.6666666666666666,
#  0.8333333333333334,
#  1.0]

# %% [markdown]
# > CDFs are implemented with two sorted lists: one list which contains the potential outcome values of your discrete distribution, and another list which contains cumulative probabilities.
#
# Following this, we now have a list of possible values and a second list containing cumulative probabilities for each value. Let's go ahead and plot these values in matplotlib using a bar plot.
# * Use `dice_lst` for x-axis and `dice_cum` for y-axis

# %%
# Your code here
import matplotlib.pyplot as plt

# Step 1: Define the lists
dice_lst = [1, 2, 3, 4, 5, 6]
dice_cum = [0.16666666666666666, 0.3333333333333333, 0.5, 0.6666666666666666, 0.8333333333333334, 1.0]

# Step 2: Create the bar plot
plt.figure(figsize=(8, 5))
plt.bar(dice_lst, dice_cum, color='skyblue', edgecolor='black')

# Step 3: Customize the plot
plt.xlabel('Dice Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of a Fair Dice Roll')
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %% [markdown]
# ## Level Up (optional)
#
# CDFs (and PMFs) can be calculated using built-in NumPy and matplotlib methods. So we don't have create custom functions to calculate these. We can draw a histogram styled CDF as shown below using the following steps
#
# You would need to perform these steps
# * Use `np.histogram()` to automatically calculate the histogram with probabilities. [Here is numpy histogram documentation](https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram.html) to help you dig deeper.
#
# * Use [`plt.scatter()`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) method with [`np.cumsum()`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.cumsum.html) to calculate and plot cumulative probabilities (just like we did above).

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the list of dice rolls
dice_lst = [1, 2, 3, 4, 5, 6, 1, 2, 2, 3, 3, 3, 4, 4, 5, 6, 6, 6, 6]

# Step 2: Calculate the histogram with probabilities
hist, bin_edges = np.histogram(dice_lst, bins=np.arange(1, 8), density=True)

# Step 3: Calculate the cumulative probabilities
cdf = np.cumsum(hist * np.diff(bin_edges))

# Step 4: Plot the CDF using plt.scatter()
plt.figure(figsize=(8, 5))
plt.scatter(bin_edges[:-1], cdf, color='skyblue', edgecolor='black')
plt.step(bin_edges[:-1], cdf, where='mid', color='skyblue', linestyle='--')

# Customize the plot
plt.xlabel('Dice Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of a Fair Dice Roll')
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %% [markdown]
# ## Summary
#
# In this lesson, we looked at developing a CDF - a percentile function of a discrete random variable. We looked at how to calculate and visualize a CDF. This technique can also be applied to continuous random variables which we shall see later in this section.
